# %% [markdown]
# # E-commerce PySpark Analysis
#
# Run the generator first, then use this notebook to inspect the processed insights.

# %%
from pyspark.sql import SparkSession
from src.config import PROCESSED_DATA_DIR

spark = SparkSession.builder.appName('EcommerceNotebook').master('local[*]').getOrCreate()

# %%
category_revenue = spark.read.option('header', True).option('inferSchema', True).csv(str(PROCESSED_DATA_DIR / 'category_revenue'))
category_revenue.show()
